# %% [markdown]
# <a href="https://colab.research.google.com/github/dimiporf/datavis/blob/main/datavis_100567030.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 10, 100)
plt.plot(x, x**2)

# %%
figure = plt.figure()
plt.plot()
# Out:
# []

# %%
x = np.linspace(0,2,100)
plt.figure(figsize=(8,6))
plt.plot(x, x, label="linear", color="#43b2a1", linewidth=1.5, linestyle="-.")
plt.plot(x, np.cos(x), label='cosine', color="red", linewidth=2, linestyle=":")
plt.plot(x, np.sin(x), label="sine", color="purple")
plt.xlabel("x label", size=13)
plt.ylabel("y label", size=13)
plt.title("Pyplot simple implementation", size=17)
plt.legend(loc="lower right")

# %%
fig, ax = plt.subplots(figsize=(8,6))
x = np.linspace(0,2,100)
ax.plot(x, x, color="black", linewidth=1.8, linestyle="-.")
ax.plot(x, np.cos(x),color="black", linewidth=1.8, linestyle="-.")
ax.plot(x, np.sin(x),color="black", linewidth=1.8, linestyle=":")
ax.set_title("Object Oriented Interface", size="14")
ax.legend(["a line (linear)", "b line (cos)", "c line (sin)"])

# %% [markdown]
# Marking points in visualization

# %%
x = np.linspace(0,3,1000)
plt.figure(figsize=(6,4))
plt.plot(x,x**2, x, 2*x)
plt.annotate('x=0', xy=(0,0), xytext=(0,1), arrowprops=dict(facecolor="black", arrowstyle="->"))
plt.annotate('x=2', xy=(2,4), xytext=(2,5), arrowprops=dict(facecolor="black", arrowstyle="->"), bbox=dict(boxstyle="round", alpha=0.2))
# Out:
# Text(2, 5, 'x=2')

# %%
import matplotlib.patches as patches
x = np.linspace(0,3,1000)
plt.plot(x, x**2, x, 2*x)

p1 = patches.Ellipse(xy=(0,0), width=0.16, height=.6, alpha=.3, facecolor="brown", edgecolor="black", linewidth=1,linestyle="solid")
p2 = patches.Ellipse(xy=(2,4), width=0.16, height=.6, alpha=.3, facecolor="brown", edgecolor="black", linewidth=1,linestyle="solid")
ax = plt.gca()
ax.add_patch(p1)
ax.add_patch(p2)

# %%
x = np.linspace(0,3,1000)
plt.plot(x, x**2, x, 2*x)

plt.axvline(2, color="red", alpha=0.4, linestyle="-.")
plt.axhline(4, color="red", alpha=0.4, linestyle="-.")

# %% [markdown]
# Create different properties for axes

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 1000)

plt.plot(x,np.sin(x))
plt.xlim(-8,8)
plt.ylim(-3,3)
plt.xticks([-2*np.pi, -np.pi,0,np.pi,2*np.pi])
plt.yticks([-1,0,1])
plt.grid(True)
plt.xlabel("x", size=13)
plt.ylabel("sin(x)", size=13)

#import from next implementation
plt.gca().xaxis.set_major_formatter(form)

# %%
def formatter(x,pos): return "${:1.0f}\pi$".format(x/np.pi)

# %%
from matplotlib.ticker import FuncFormatter
form = FuncFormatter(formatter)

# %% [markdown]
# IRIS DATASET EXAMPLE

# %%
import sklearn.datasets as ds

iris = ds.load_iris()
iris_x = iris['data']
iris_y = iris['target']
iris_x_labels = iris['feature_names']
iris_y_labels = iris['target_names']

setosa= np.where(iris_y == 0)
versicolor = np.where(iris_y == 1)
virginica = np.where(iris_y == 2)

# %%
(unique, counts) =np.unique(iris_y, return_counts=True)
plt.figure(figsize=(6,6))

plt.pie(counts, labels=iris_y_labels, autopct='%1.1f%%', shadow=True, explode=(0.05, 0,0))
# Out:
# ([<matplotlib.patches.Wedge at 0x7f4c8a8fd630>,
# ...
#  [Text(0.5749999689181257, 0.9959292322972324, 'setosa'),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, 'versicolor'),
#   Text(0.5500001486524352, -0.9526278583383436, 'virginica')],
#  [Text(0.324999982431984, 0.5629165226027835, '33.3%'),
#   Text(-0.5999999999999974, -5.6176054134900006e-08, '33.3%'),
#   Text(0.30000008108314646, -0.5196151954572783, '33.3%')])

# %% [markdown]
# PIECHART STYLE

# %%
plt.figure(figsize=(5,5))
plt.pie(counts, labels=iris_y_labels, autopct='%1.1f%%', textprops={'fontsize': 12}, wedgeprops={'edgecolor': 'white'})

circle = plt.Circle(xy=(0,0), radius=0.7, color='white')
plt.gca().add_artist(circle)
plt.title('Class Distribution Chart', size=14)
# Out:
# Text(0.5, 1.0, 'Class Distribution Chart')

# %% [markdown]
# Telling difference in characteristics from data parsing

# %%
formatter = FuncFormatter(lambda v, _: iris_y_labels[v])

# %%
plt.figure(figsize=(7,5))
plt.scatter(iris_x[:,2], iris_x[:,3], c=iris_y, edgecolor='k')
plt.xlabel(iris_x_labels[2])
plt.ylabel(iris_x_labels[3])

plt.title("Petal width/height by species", size=14)
plt.colorbar(ticks=[0,1,2], format=formatter)

# %% [markdown]
# Length can lead to help?

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import load_iris

# Load the Iris dataset

iris_x_labels = iris.feature_names

# Create the figure and 3D axes
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Set the labels for each axis
ax.set_xlabel(iris_x_labels[2])
ax.set_ylabel(iris_x_labels[3])
ax.set_zlabel(iris_x_labels[0])

# Plot the data points in 3D
scatter = ax.scatter(iris_x[:, 2], iris_x[:, 3], iris_x[:, 0], edgecolor='k', c=iris_y, s=40)

handles, _ = scatter.legend_elements()
legend = ax.legend(handles, iris_y_labels, loc="upper left", title="Species")
ax.add_artist(legend)

# Show the plot
ax.view_init(elev=-160, azim=130)
plt.show()
